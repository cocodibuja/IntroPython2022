# %% [markdown]
# <a href="https://colab.research.google.com/github/cocodibuja/IntroPython2022/blob/main/IntroPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# ¿Cómo se crea un dataframe? 🤔
